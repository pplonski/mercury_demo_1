# %% [raw]
# ---
# title: Tips dashboard
# description: Explore tips dataset
# show-code: False
# params:
#     hue:
#         input: select
#         label: Select hue
#         value: smoker
#         choices: [smoker, sex, time, day]
# ---

# %%
hue = "smoker"

# %% [markdown]
# # Tips explorer

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
_=sns.pairplot(tips, hue=hue)
